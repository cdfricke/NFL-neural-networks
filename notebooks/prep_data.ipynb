# %% [markdown]
# ## Importing Data

# %%
import pandas as pd
import numpy as np
import plotly_express as px

# %%
years = [x for x in range(2009,2020)]

# PBP Data
preseason_pbp = {}
regseason_pbp = {}
pstseason_pbp = {}
for year in years:
    preseason_pbp[year] = pd.read_csv(f"../cleaned_data/pbp_data/pre_season/pre_pbp_{year}.csv", low_memory=False)
    regseason_pbp[year] = pd.read_csv(f"../cleaned_data/pbp_data/regular_season/reg_pbp_{year}.csv", low_memory=False)
    pstseason_pbp[year] = pd.read_csv(f"../cleaned_data/pbp_data/post_season/post_pbp_{year}.csv", low_memory=False)

all_pre_pbp = pd.concat(preseason_pbp)
all_reg_pbp = pd.concat(regseason_pbp)
all_pst_pbp = pd.concat(pstseason_pbp)

df_pbp = pd.concat([all_pre_pbp, all_reg_pbp, all_pst_pbp])

# Make sure there are no duplicates, drop stupid columns, fill nans, etc
print(df_pbp.shape)
df_pbp.drop(columns=['Unnamed: 0','play_id'], inplace=True)
df_pbp.fillna(value=0)
df_pbp.drop_duplicates(inplace=True)
print(df_pbp.shape)
# Out:
# (614497, 257)
# (614496, 255)

# %%
# GAME DATA
preseason_games = {}
regseason_games = {}
pstseason_games = {}
for year in years:
    preseason_games[year] = pd.read_csv(f"../data/games_data/pre_season/pre_games_{year}.csv")
    regseason_games[year] = pd.read_csv(f"../data/games_data/regular_season/reg_games_{year}.csv")
    pstseason_games[year] = pd.read_csv(f"../data/games_data/post_season/post_games_{year}.csv")

all_pre_games = pd.concat(preseason_games)
all_reg_games = pd.concat(regseason_games)
all_pst_games = pd.concat(pstseason_games)

df_games = pd.concat([all_pre_games, all_reg_games, all_pst_games])

# Make sure there are no duplicates, drop stupid columns, fill nans, etc
print(df_games.shape)
df_games.drop(columns='Unnamed: 0', inplace=True)
df_games.dropna(inplace=True)
df_games.drop_duplicates(inplace=True)
print(df_games.shape)
# Out:
# (3661, 11)
# (3660, 10)

# %% [markdown]
# ## Preprocessing

# %%
# get numeric features
df_pbp_numeric = df_pbp.select_dtypes(include="number")
features = df_pbp_numeric.columns.tolist()
df_pbp_numeric.describe()
# Out:
#               season       game_id   yardline_100  quarter_seconds_remaining  \
# count  614496.000000  6.144960e+05  614496.000000              614496.000000
# mean     2014.006993  2.014162e+09      50.135991                 424.722428
# std         3.152465  3.148374e+06      24.980828                 273.033294
# min      2009.000000  2.009081e+09       1.000000                   0.000000
# 25%      2011.000000  2.011121e+09      31.000000                 174.000000
# 50%      2014.000000  2.014102e+09      53.000000                 412.000000
# 75%      2017.000000  2.017092e+09      71.000000                 661.000000
# max      2019.000000  2.020020e+09      99.000000                 900.000000
#
#        half_seconds_remaining  game_seconds_remaining  quarter_end  \
# count           614496.000000           614496.000000     614496.0
# mean               825.880450             1722.409313          0.0
# std                547.359029             1038.468246          0.0
# min                  0.000000                0.000000          0.0
# 25%                317.000000              821.000000          0.0
# 50%                812.000000             1800.000000          0.0
# 75%               1299.000000             2591.000000          0.0
# max               1800.000000             3600.000000          0.0
#
#                drive             sp            qtr  ...  lateral_recovery  \
# count  614496.000000  614496.000000  614496.000000  ...     614496.000000
# mean       12.119815       0.071548       2.563719  ...          0.001941
# std         7.010383       0.257738       1.120667  ...          0.044019
# min         1.000000       0.000000       1.000000  ...          0.000000
# 25%         6.000000       0.000000       2.000000  ...          0.000000
# 50%        12.000000       0.000000       3.000000  ...          0.000000
# 75%        18.000000       0.000000       4.000000  ...          0.000000
# max        38.000000       1.000000       6.000000  ...          1.000000
#
#        fumble_recovery_1_yards  fumble_recovery_2_yards   return_yards  \
# count            614496.000000            614496.000000  614496.000000
# mean                  0.030913                 0.000474       1.021745
# std                   1.078881                 0.139259       5.398683
# min                 -34.000000                -3.000000     -16.000000
# 25%                   0.000000                 0.000000       0.000000
# 50%                   0.000000                 0.000000       0.000000
# 75%                   0.000000                 0.000000       0.000000
# max                 106.000000                77.000000     109.000000
#
#        penalty_yards  replay_or_challenge  defensive_two_point_attempt  \
# count  614496.000000        614496.000000                614496.000000
# mean        0.656053             0.008492                     0.000063
# std         2.715012             0.091757                     0.007966
# min         0.000000             0.000000                     0.000000
# 25%         0.000000             0.000000                     0.000000
# 50%         0.000000             0.000000                     0.000000
# 75%         0.000000             0.000000                     0.000000
# max        66.000000             1.000000                     1.000000
#
#        defensive_two_point_conv  defensive_extra_point_attempt  \
# count             614496.000000                       614496.0
# mean                   0.000016                            0.0
# std                    0.004034                            0.0
# min                    0.000000                            0.0
# 25%                    0.000000                            0.0
# 50%                    0.000000                            0.0
# 75%                    0.000000                            0.0
# max                    1.000000                            0.0
#
#        defensive_extra_point_conv
# count                    614496.0
# mean                          0.0
# std                           0.0
# min                           0.0
# 25%                           0.0
# 50%                           0.0
# 75%                           0.0
# max                           0.0
#
# [8 rows x 149 columns]

# %%
for idx, feature in enumerate(df_pbp_numeric.columns):
    print(feature, idx)
# Out:
# season 0
# game_id 1
# yardline_100 2
# quarter_seconds_remaining 3
# half_seconds_remaining 4
# game_seconds_remaining 5
# quarter_end 6
# drive 7
# sp 8
# qtr 9
# down 10
# goal_to_go 11
# ydstogo 12
# ydsnet 13
# yards_gained 14
# shotgun 15
# no_huddle 16
# qb_dropback 17
# qb_kneel 18
# qb_spike 19
# qb_scramble 20
# air_yards 21
# yards_after_catch 22
# kick_distance 23
# home_timeouts_remaining 24
# away_timeouts_remaining 25
# timeout 26
# posteam_timeouts_remaining 27
# defteam_timeouts_remaining 28
# total_home_score 29
# total_away_score 30
# posteam_score 31
# defteam_score 32
# score_differential 33
# posteam_score_post 34
# defteam_score_post 35
# score_differential_post 36
# no_score_prob 37
# opp_fg_prob 38
# opp_safety_prob 39
# opp_td_prob 40
# fg_prob 41
# safety_prob 42
# td_prob 43
# extra_point_prob 44
# two_point_conversion_prob 45
# ep 46
# epa 47
# total_home_epa 48
# total_away_epa 49
# total_home_rush_epa 50
# total_away_rush_epa 51
# total_home_pass_epa 52
# total_away_pass_epa 53
# air_epa 54
# yac_epa 55
# comp_air_epa 56
# comp_yac_epa 57
# total_home_comp_air_epa 58
# total_away_comp_air_epa 59
# total_home_comp_yac_epa 60
# total_away_comp_yac_epa 61
# total_home_raw_air_epa 62
# total_away_raw_air_epa 63
# total_home_raw_yac_epa 64
# total_away_raw_yac_epa 65
# wp 66
# def_wp 67
# home_wp 68
# away_wp 69
# wpa 70
# home_wp_post 71
# away_wp_post 72
# total_home_rush_wpa 73
# total_away_rush_wpa 74
# total_home_pass_wpa 75
# total_away_pass_wpa 76
# air_wpa 77
# yac_wpa 78
# comp_air_wpa 79
# comp_yac_wpa 80
# total_home_comp_air_wpa 81
# total_away_comp_air_wpa 82
# total_home_comp_yac_wpa 83
# total_away_comp_yac_wpa 84
# total_home_raw_air_wpa 85
# total_away_raw_air_wpa 86
# total_home_raw_yac_wpa 87
# total_away_raw_yac_wpa 88
# punt_blocked 89
# first_down_rush 90
# first_down_pass 91
# first_down_penalty 92
# third_down_converted 93
# third_down_failed 94
# fourth_down_converted 95
# fourth_down_failed 96
# incomplete_pass 97
# touchback 98
# interception 99
# punt_inside_twenty 100
# punt_in_endzone 101
# punt_out_of_bounds 102
# punt_downed 103
# punt_fair_catch 104
# kickoff_inside_twenty 105
# kickoff_in_endzone 106
# kickoff_out_of_bounds 107
# kickoff_downed 108
# kickoff_fair_catch 109
# fumble_forced 110
# fumble_not_forced 111
# fumble_out_of_bounds 112
# solo_tackle 113
# safety 114
# penalty 115
# tackled_for_loss 116
# fumble_lost 117
# own_kickoff_recovery 118
# own_kickoff_recovery_td 119
# qb_hit 120
# rush_attempt 121
# pass_attempt 122
# sack 123
# touchdown 124
# pass_touchdown 125
# rush_touchdown 126
# return_touchdown 127
# extra_point_attempt 128
# two_point_attempt 129
# field_goal_attempt 130
# kickoff_attempt 131
# punt_attempt 132
# fumble 133
# complete_pass 134
# assist_tackle 135
# lateral_reception 136
# lateral_rush 137
# lateral_return 138
# lateral_recovery 139
# fumble_recovery_1_yards 140
# fumble_recovery_2_yards 141
# return_yards 142
# penalty_yards 143
# replay_or_challenge 144
# defensive_two_point_attempt 145
# defensive_two_point_conv 146
# defensive_extra_point_attempt 147
# defensive_extra_point_conv 148

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# fit the scaler and use it to transform the data
# we will arbitrarily take columns 7 and onward
df_scaled = scaler.fit_transform(df_pbp_numeric.iloc[:,7:])
df_scaled = pd.DataFrame(df_scaled, columns=df_pbp_numeric.columns[7:])

df_scaled.describe()
# Out:
#                drive             sp            qtr           down  \
# count  614496.000000  614496.000000  614496.000000  614496.000000
# mean        0.300536       0.071548       0.312744       0.442223
# std         0.189470       0.257738       0.224133       0.286526
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.135135       0.000000       0.200000       0.250000
# 50%         0.297297       0.000000       0.400000       0.500000
# 75%         0.459459       0.000000       0.600000       0.750000
# max         1.000000       1.000000       1.000000       1.000000
#
#           goal_to_go        ydstogo         ydsnet   yards_gained  \
# count  614496.000000  614496.000000  614496.000000  614496.000000
# mean        0.049649       0.158420       0.622102       0.306668
# std         0.217219       0.099276       0.140905       0.057439
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.083333       0.500000       0.277372
# 50%         0.000000       0.208333       0.586022       0.277372
# 75%         0.000000       0.208333       0.725806       0.321168
# max         1.000000       1.000000       1.000000       1.000000
#
#              shotgun      no_huddle  ...  lateral_recovery  \
# count  614496.000000  614496.000000  ...     614496.000000
# mean        0.416894       0.065166  ...          0.001941
# std         0.493046       0.246818  ...          0.044019
# min         0.000000       0.000000  ...          0.000000
# 25%         0.000000       0.000000  ...          0.000000
# 50%         0.000000       0.000000  ...          0.000000
# 75%         1.000000       0.000000  ...          0.000000
# max         1.000000       1.000000  ...          1.000000
#
#        fumble_recovery_1_yards  fumble_recovery_2_yards   return_yards  \
# count            614496.000000            614496.000000  614496.000000
# mean                  0.243078                 0.037506       0.136174
# std                   0.007706                 0.001741       0.043189
# min                   0.000000                 0.000000       0.000000
# 25%                   0.242857                 0.037500       0.128000
# 50%                   0.242857                 0.037500       0.128000
# 75%                   0.242857                 0.037500       0.128000
# max                   1.000000                 1.000000       1.000000
#
#        penalty_yards  replay_or_challenge  defensive_two_point_attempt  \
# count  614496.000000        614496.000000                614496.000000
# mean        0.009940             0.008492                     0.000063
# std         0.041137             0.091757                     0.007966
# min         0.000000             0.000000                     0.000000
# 25%         0.000000             0.000000                     0.000000
# 50%         0.000000             0.000000                     0.000000
# 75%         0.000000             0.000000                     0.000000
# max         1.000000             1.000000                     1.000000
#
#        defensive_two_point_conv  defensive_extra_point_attempt  \
# count             614496.000000                       614496.0
# mean                   0.000016                            0.0
# std                    0.004034                            0.0
# min                    0.000000                            0.0
# 25%                    0.000000                            0.0
# 50%                    0.000000                            0.0
# 75%                    0.000000                            0.0
# max                    1.000000                            0.0
#
#        defensive_extra_point_conv
# count                    614496.0
# mean                          0.0
# std                           0.0
# min                           0.0
# 25%                           0.0
# 50%                           0.0
# 75%                           0.0
# max                           0.0
#
# [8 rows x 142 columns]

# %% [markdown]
# ## Game Length

# %%
game_length = {}
old_id = df_pbp_numeric['game_id'].iloc[0]
count_plays = 1
for index, row in df_pbp_numeric.iterrows():
    if row.game_id != old_id:
        game_length[row.game_id] = count_plays
        old_id = row.game_id
        count_plays = 1
    else: 
        count_plays += 1

# %%
df_hist = pd.DataFrame({'num_plays': game_length.values()})

fig = px.histogram(df_hist, x='num_plays', 
                   labels={'num_plays':'# of plays'},
                   title='Distribution of Game Duration in # of Plays')
fig.show()
# Out:
# <div>                            <div id="7ee21fb3-2580-432e-9b32-28577228fed2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ee21fb3-2580-432e-9b32-28577228fed2")) {                    Plotly.newPlot(                        "7ee21fb3-2580-432e-9b32-28577228fed2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"# of plays=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":